# %% [markdown]
# <a href="https://colab.research.google.com/github/Maddyben/Introduction-to-Machine-Learning/blob/master/IBM%20Assignment%20-%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/HOUSE.csv')

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#UNIVARIATE ANALYSIS

# %%
plt.hist(df['number of bathrooms'])
# Out:
# (array([2.559e+03, 3.037e+03, 6.379e+03, 1.765e+03, 6.860e+02, 1.450e+02,
#         3.500e+01, 7.000e+00, 3.000e+00, 4.000e+00]),
#  array([0.5 , 1.25, 2.  , 2.75, 3.5 , 4.25, 5.  , 5.75, 6.5 , 7.25, 8.  ]),
#  <BarContainer object of 10 artists>)

# %%
df.boxplot(column="number of floors")
# Out:
# <Axes: >

# %%
#BIVARIATE ANALYSIS

# %%
sns.barplot(x="Built Year",y="condition of the house",data=df)
# Out:
# <Axes: xlabel='Built Year', ylabel='condition of the house'>

# %%
sns.countplot(x="number of views",data=df)
# Out:
# <Axes: xlabel='number of views', ylabel='count'>

# %%
sns.violinplot(x="Built Year",y="condition of the house",data=df)
# Out:
# <Axes: xlabel='Built Year', ylabel='condition of the house'>

# %%
#MULTIVARIATE ANALYSIS

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
#DESCRIPTIVE STATISTICS

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
#NULL HANDLING

# %%
df.isna().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...
